# %% [markdown]
# #Analysing Speed of Retrieval of code:

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/zeelpatel7/Measuring-Chatbot-Efficiency/main/Data%20Files/Speed%20of%20Code%20Retrieval.csv'
speed = pd.read_csv(url)
print(speed)
# Out:
#    Language                   Code              ChatGPT Success rate  \
# 0    Python       Fibonacci Series     7.07, 7.49, 6.66         100%
# 1   Python   Reversing Linked List   8.72, 11.92, 11.82         100%
# 2   Python           BFS algorithm     7.83, 8.26, 9.02         100%
# 3   Python              Merge Sort  11.76, 11.25, 13.02         100%
# 4    Python    Fractional Knapsack  15.21, 13.92, 15.09         100%
# 5      Java       Fibonacci Series   11.42, 8.27, 19.38         100%
# 6      Java  Reversing Linked List   9.79, 14.96, 15.34         100%
# 7      Java          BFS algorithm  11.26, 20.15, 10.87         100%
# 8      Java             Merge Sort  19.05, 18.69, 20.18         100%
# 9      Java    Fractional Knapsack  18.99, 19.90, 18.74         100%
# 10      CPP       Fibonacci Series     6.05, 5.65, 7.44         100%
# 11      CPP  Reversing Linked List   10.32, 9.75, 18.06         100%
# 12      CPP          BFS algorithm  13.75, 13.33, 14.06         100%
# ...

# %% [markdown]
# ###CHATGPT Graphical Representation

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

print(speed['Min Max Scaling'])
X1= speed['Min Max Scaling']
y1 = [*range(1,16,1)]
x1 = X1
scaler1 = MinMaxScaler()

plt.plot(y1, x1, c = '#43434c' )
plt.xlabel ("Serial Number")
plt.ylabel("Min Max Scaling of ChatGPT")
plt.ylim([0,1])
plt.xlim([0,15])

plt.show()
# Out:
# 0     0.069
# 1     0.239
# 2     0.128
# 3     0.294
# 4     0.418
# 5     0.339
# 6     0.355
# 7     0.388
# 8     0.625
# 9     0.620
# 10    0.037
# 11    0.325
# 12    0.371
# 13    0.559
# 14    0.516
# Name: Min Max Scaling, dtype: float64

# %% [markdown]
# ### Google Bard Graphical Representation

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

print(speed['Min Max Scaling.1'])
X2= speed['Min Max Scaling.1']
y2 = [*range(1,16,1)]
x2 = X2
scaler1 = MinMaxScaler()

plt.plot(y2, x2, c ="#416171")
plt.xlabel ("Serial Number")
plt.ylabel("Min Max Scaling of Google Bard")
plt.ylim([0,1])
plt.xlim([0,15])

plt.show()
# Out:
# 0     0.105
# 1     0.158
# 2     0.151
# 3     0.154
# 4     0.121
# 5     0.088
# 6     0.128
# 7     0.289
# 8     0.384
# 9     0.498
# 10    0.243
# 11    0.182
# 12    0.192
# 13    0.481
# 14    0.434
# Name: Min Max Scaling.1, dtype: float64

# %% [markdown]
# ### Chat Sonic Graphical Representation

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

print(speed['Min Max Scaling.2'])
X3= speed['Min Max Scaling.2']
y3 = [*range(1,16,1)]
x3 = X3
scaler1 = MinMaxScaler()

plt.plot(y3, x3, c ="#349e97")
plt.xlabel ("Serial Number")
plt.ylabel("Min Max Scaling of Chat Sonic")
plt.ylim([0,1])
plt.xlim([0,15])

plt.show()
# Out:
# 0     0.000
# 1     0.067
# 2     0.047
# 3     0.101
# 4     0.149
# 5     0.012
# 6     0.082
# 7     0.146
# 8     0.271
# 9     0.141
# 10    0.018
# 11    0.077
# 12    0.199
# 13    0.209
# 14    0.105
# Name: Min Max Scaling.2, dtype: float64

# %% [markdown]
# ### Perplexity Graphical Representation

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

print(speed['Min Max Scaling.3'])
X4= speed['Min Max Scaling.3']
y4 = [*range(1,16,1)]
x4 = X4
scaler1 = MinMaxScaler()

plt.plot(y4, x4, c ="#84e0a1")
plt.xlabel ("Serial Number")
plt.ylabel("Min Max Scaling of Perplexity")
plt.ylim([0,1])
plt.xlim([0,15])

plt.show()
# Out:
# 0     0.059
# 1     0.038
# 2     0.049
# 3     0.106
# 4     0.166
# 5     0.049
# 6     0.030
# 7     0.101
# 8     0.184
# 9     0.149
# 10    0.142
# 11    0.021
# 12    0.185
# 13    0.164
# 14    0.086
# Name: Min Max Scaling.3, dtype: float64

# %% [markdown]
# ### Microsoft Bing AI Graphical Representation

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

print(speed['Min Max Scaling.4'])
X5= speed['Min Max Scaling.4']
y5 = [*range(1,16,1)]
x5 = X5
scaler1 = MinMaxScaler()

plt.plot(y5, x5, c ="#80d646")
plt.xlabel ("Serial Number")
plt.ylabel("Min Max Scaling of Microsoft Bing AI")
plt.ylim([0,1])
plt.xlim([0,15])

plt.show()
# Out:
# 0     0.684
# 1     1.000
# 2     0.901
# 3       NaN
# 4       NaN
# 5     0.362
# 6     0.864
# 7     0.645
# 8       NaN
# 9       NaN
# 10    0.737
# 11    0.781
# 12    0.625
# 13      NaN
# 14      NaN
# Name: Min Max Scaling.4, dtype: float64

# %% [markdown]
# ## Plot of all chatbots

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

plt.plot(y5, x5, c ="#676767")
plt.plot(y4, x4, c ="#CC5500")
plt.plot(y3, x3, c = '#83872e')
plt.plot(y2, x2, c ="#ECA72C")
plt.plot(y1, x1, c ="#6A041D")
plt.legend(["Bing", "Perplexity", "Chat Sonic", "Bard", "ChatGPT"])

plt.xlabel ("Serial Number")
plt.ylabel("Min Max Scaling")
plt.title("Speed of Code Retrieval")
plt.show()
